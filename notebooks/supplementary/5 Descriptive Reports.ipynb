# %%
from python.acnets.pipeline import ConnectivityPipeline

# %%
conn_pipe = ConnectivityPipeline(atlas='seitzman2018')
conn_pipe.fit(None)
conn_pipe.get_feature_names_out()
# Out:
#                                          Auditory  \
# Auditory                                 Auditory
# CinguloOpercular      CinguloOpercular ↔ Auditory
# DefaultMode                DefaultMode ↔ Auditory
# DorsalAttention        DorsalAttention ↔ Auditory
# FrontoParietal          FrontoParietal ↔ Auditory
# MedialTemporalLobe  MedialTemporalLobe ↔ Auditory
# ParietoMedial            ParietoMedial ↔ Auditory
# Reward                          Reward ↔ Auditory
# Salience                      Salience ↔ Auditory
# SomatomotorDorsal    SomatomotorDorsal ↔ Auditory
# SomatomotorLateral  SomatomotorLateral ↔ Auditory
# VentralAttention      VentralAttention ↔ Auditory
# Visual                          Visual ↔ Auditory
# unassigned                  unassigned ↔ Auditory
#
#                                          CinguloOpercular  \
# Auditory                      Auditory ↔ CinguloOpercular
# CinguloOpercular                         CinguloOpercular
# ...
